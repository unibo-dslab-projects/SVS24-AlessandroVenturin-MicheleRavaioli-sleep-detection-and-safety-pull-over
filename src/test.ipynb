# %% [markdown]
# # Test inattention detector

# %%
from inattention.detector import InattentionDetector, WebcamCameraStream

# %%
cam = WebcamCameraStream()
detector = InattentionDetector(cam)
# Out:
# [ WARN:0@168.430] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@168.430] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_28594/508202395.py in <module>
# ----> 1 cam = WebcamCameraStream()
#       2 detector = InattentionDetector(cam)
#
# ~/Desktop/Uni/sleep-detection-and-safety-pull-over/src/inattention/detector.py in __init__(self, device, width, height, flip)
#     104         self._cap = cv2.VideoCapture(self.device)
#     105         if not self._cap.isOpened():
# --> 106             raise RuntimeError(f"Could not open camera device {self.device}")
#     107
#     108         # Optionally set resolution
#
# RuntimeError: Could not open camera device 0
